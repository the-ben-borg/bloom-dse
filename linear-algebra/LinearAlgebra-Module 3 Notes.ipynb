# %% [markdown]
# #### Functions
#     - Python function for f(x) = 1/ x + 1

# %%
def f(x): return 1.0/ x + 1

f(5)
# Out:
# 1.2

# %%
f(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-6bfbdbfff9c4> in <module>
# ----> 1 f(0)
#
# <ipython-input-7-ba1584c81b18> in f(x)
# ----> 1 def f(x): return 1.0/ x + 1
#       2
#       3 f(5)
#
# ZeroDivisionError: float division by zero

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x): return 1.0 / x + 1
x = np.linspace(0, 2, 101)
plt.plot(x, f(x))
plt.show()
# Out:
# <ipython-input-6-4e3bb382110c>:5: RuntimeWarning: divide by zero encountered in true_divide
#   def f(x): return 1.0 / x + 1

# %%
def f(x): return 1.0 / x + 1
x = np.linspace(0, 2, 101)
plt.plot(x, f(x), label="$y=f(x)$")
plt.plot(np.linspace(0.375, 0.375, 101), np.linspace(0, 50, 101), label="A Vertical Line")
plt.show()
# Out:
# <ipython-input-9-d83c6780e0ae>:1: RuntimeWarning: divide by zero encountered in true_divide
#   def f(x): return 1.0 / x + 1

# %% [markdown]
# $f(x) = 2x^3 - 3x^2 + 9$

# %%
def f(x):
    return 2*(x**3)-3*(x**2)+9

f(1)
# Out:
# 8

# %%
f(3)
# Out:
# 36

# %%
x = np.linspace(-2, 2, 101)
plt.plot(x, f(x))
plt.plot(x, np.linspace(0, 0, 101))
plt.show()

# %%
from scipy.optimize import fsolve
print (fsolve(f, -1.3))
# Out:
# [-1.27372234]

# %% [markdown]
# #### Exponential Functions
# - Most important exponential function:
# $f(x) = e^x$
# $e$ is **Euler's Number**

# %%
import numpy as np
print (np.e**2)
print (np.exp(2))
# Out:
# 7.3890560989306495
# 7.38905609893065

# %%
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 101)

plt.plot(x, np.e**x, label="$e^x$")
plt.plot(x, 2**x, label="$2^x$")
plt.plot(x, 1**x, label="$1^x$")
plt.plot(x, 0.5**x, label="$(1/2)^x$")
plt.plot(x, (1/np.e)**x, label="$(1/e)^x$")
plt.plot(x, np.linspace(0, 0, 101), label="$x$-axis")
plt.legend()
plt.show()
